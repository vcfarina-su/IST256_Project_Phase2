# %%
## Successfully loaded EWG database info
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np


ewg_data = requests.get('https://www.ewg.org/skindeep/product/707461/Boyzz_Only_No_Nonsense_Hair_%26_Body_Wash/')
ewg_data_html = BeautifulSoup(ewg_data.text, 'html.parser')
ewg_data_js = ewg_data_html 

#text = ewg_data_read.find('div', {'class' : 'body'})
#print(text)

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import numpy as np
import json
  
url = 'https://toxnet.nlm.nih.gov/cpdb/chemnameindex.html'
response = requests.get(url)
js = response.json()
type(js)
# text = json.dumps(htmlContent.text)
# info = json.loads(text.decode("utf-8"))

#CP_data()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-2-ec189c3c1d71> in <module>()
#       7 url = 'https://toxnet.nlm.nih.gov/cpdb/chemnameindex.html'
#       8 response = requests.get(url)
# ----> 9 js = response.json()
#      10 type(js)
#      11 # text = json.dumps(htmlContent.text)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/requests/models.py in json(self, **kwargs)
#     894                     # used.
#     895                     pass
# --> 896         return complexjson.loads(self.text, **kwargs)
#     897
#     898     @property
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
from usda.client import UsdaClient

client = UsdaClient("2pqBXdyMiLbji47gZkeolk0nVi9oaOCn5TuRoncP")
client

# %%
#USDA Food Composition API 

import pandas as pd
import json
import requests

product = input("Enter Product Name: ")

#Get ndb product number
def ndb_search(product):
    url = 'https://api.nal.usda.gov/ndb/search'
    key = 'uC7EeReDRVWw7Kzijvvn8LtCDWR3D6hPyksxuFTW'
    params = (('format', 'json'),('q', product),('api_key', key))
    response = requests.get(url, params = params)
    products = response.json()['list']['item']
    products_df = pd.DataFrame(products)     
    product_ndb = pd.DataFrame(products_df['ndbno']).head(1)
    ndb_int = int(product_ndb['ndbno'])
    
    return ndb_int




#Get product ingredients list using NDB number 
def ndb_report(product_ndb):
    url = 'https://api.nal.usda.gov/ndb/V2/reports'
    key = 'uC7EeReDRVWw7Kzijvvn8LtCDWR3D6hPyksxuFTW'
    params = (('ndbno', product_ndb),('type', 'f'),('format', 'json'),('api_key', key))
    url = 'https://api.nal.usda.gov/ndb/V2/reports'
    response = requests.get(url, params = params)
    data_list = response.json()['foods'][0]

    #ingredients = data_list['food']['ing']
  
    #return ingredients['desc'].split(',')
    return data_list


product_ndb = ndb_search(product)
ingredients_report = ndb_report(product_ndb)



#ingredients_report
# Out:
# Enter Product Name: Cheetos Puffs

# %%
url = 'https://api.nal.usda.gov/ndb/search'
key = 'uC7EeReDRVWw7Kzijvvn8LtCDWR3D6hPyksxuFTW'
params = (('format', 'json'),('q', 'Tropicana'),('api_key', key))
response = requests.get(url, params = params)
groups = response.json()['list']['item']
for i in range(len(groups)):
   print(groups[i]['group'])
    
products
# Out:
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# Branded Food Products Database
# [{'offset': 0,
#   'group': 'Snacks',
#   'name': 'Snacks, vegetable chips, HAIN CELESTIAL GROUP, TERRA CHIPS',
#   'ndbno': '25030',
#   'ds': 'SR',
#   'manu': 'none'},
#  {'offset': 1,
#   'group': 'Branded Food Products Database',
#   'name': 'GROUP RAISED CALF LIVER SLICES, UPC: 636289082408',
#   'ndbno': '45366075',
#   'ds': 'LI',
#   'manu': 'Strauss Brands Incorporated'},
#  {'offset': 2,
#   'group': 'Branded Food Products Database',
#   'name': 'RENAISSANCE FOOD GROUP LLC, TURKEY SUB, UPC: 826766142248',
#   'ndbno': '45243372',
#   'ds': 'LI',
#   'manu': 'RENAISSANCE FOOD GROUP, LLC'},
#  {'offset': 3,
#   'group': 'Branded Food Products Database',
#   'name': 'THE CACAO GROUP, MILK CHOCOLATE MINT TRUFFLE BAR, UPC: 891748000458',
#   'ndbno': '45160088',
#   'ds': 'LI',
#   'manu': 'none'},
#  {'offset': 4,
#   'group': 'Branded Food Products Database',
#   'name': 'THE CACAO GROUP, LIFE IS BETTER WITH FRIENDS & CHOCOLATE, UPC: 891748000342',
#   'ndbno': '45250986',
#   'ds': 'LI',
#   'manu': 'DK Truffles LLC'},
#  {'offset': 5,
#   'group': 'Branded Food Products Database',
#   'name': 'RENAISSANCE FOOD GROUP, SPICY GUACAMOLE, UPC: 826766144211',
#   'ndbno': '45109160',
#   'ds': 'LI',
#   'manu': 'RENAISSANCE FOOD GROUP, LLC'},
#  {'offset': 6,
#   'group': 'Branded Food Products Database',
#   'name': 'RENAISSANCE FOOD GROUP, LLC, MILD GUACAMOLE, UPC: 826766144204',
#   'ndbno': '45109166',
#   'ds': 'LI',
#   'manu': 'RENAISSANCE FOOD GROUP, LLC'},
#  {'offset': 7,
#   'group': 'Branded Food Products Database',
#   'name': 'PRAIM GROUP, MILK CHOCOLATE BARS, UPC: 898136005781',
#   'ndbno': '45160140',
#   'ds': 'LI',
#   'manu': 'none'},
#  {'offset': 8,
#   'group': 'Branded Food Products Database',
#   'name': 'RENAISSANCE FOOD GROUP LLC, BUFFALO CHICKEN WRAP, UPC: 826766142217',
#   'ndbno': '45104417',
#   'ds': 'LI',
#   'manu': 'RENAISSANCE FOOD GROUP, LLC'},
#  {'offset': 9,
#   'group': 'Branded Food Products Database',
#   'name': 'RENAISSANCE FOOD GROUP LLC, HAM SUB, UPC: 826766142255',
#   'ndbno': '45104406',
#   'ds': 'LI',
#   'manu': 'RENAISSANCE FOOD GROUP, LLC'},
#  {'offset': 10,
#   'group': 'Branded Food Products Database',
#   'name': 'AMERICAN FOODS GROUP FLAME BROILED BEEF PATTY 282-1.7 OUNCE  PORTIONS PER 30 POUND NET WEIGHT MASTER CASE, UNPREPARED, GTIN: 10088374908150',
#   'ndbno': '45244123',
#   'ds': 'GDSN',
#   'manu': "King's Command Food, Inc."},
#  {'offset': 11,
#   'group': 'Branded Food Products Database',
#   'name': 'AMERICAN FOODS GROUP BEEF CUBED STEAK 20-8 OUNCE STEAKS PER 10 POUND NET WEIGHT MASTER CASE, UNPREPARED, GTIN: 10096423688106',
#   'ndbno': '45244229',
#   'ds': 'GDSN',
#   'manu': 'Green Bay Dressed Beef LLC'},
#  {'offset': 12,
#   'group': 'Branded Food Products Database',
#   'name': 'AMERICAN FOODS GROUP BEEF CUBED STEAK 20-8 OUNCE STEAKS PER 10 POUND NET WEIGHT MASTER CASE, UNPREPARED, GTIN: 10096423680384',
#   'ndbno': '45244230',
#   'ds': 'GDSN',
#   'manu': 'GREEN BAY DRESSED BEEF, LLC'},
#  {'offset': 13,
#   'group': 'Branded Food Products Database',
#   'name': 'AMERICAN FOODS GROUP BEEF CUBED STEAK 40-4 OUNCE STEAKS PER 10 POUND NET WEIGHT MASTER CASE, UNPREPARED, GTIN: 10096423680346',
#   'ndbno': '45244231',
#   'ds': 'GDSN',
#   'manu': 'GREEN BAY DRESSED BEEF, LLC'},
#  {'offset': 14,
#   'group': 'Branded Food Products Database',
#   'name': 'AMERICAN FOODS GROUP BEEF CUBED STEAK 30-5.3 OUNCE STEAKS PER 10 POUND NET WEIGHT MASTER CASE, UNPREPARED, GTIN: 10096423680353',
#   'ndbno': '45244232',
#   'ds': 'GDSN',
#   'manu': 'GREEN BAY DRESSED BEEF, LLC'},
#  {'offset': 15,
#   'group': 'Branded Food Products Database',
#   'name': 'AMERICAN FOODS GROUP GROUND BEEF FINE 73% LEAN 27% FAT, 12-3 POUND CHUBS PER 36 POUND NET WEIGHT MASTER CASE, UNPREPARED, GTIN: 00096423401289',
#   'ndbno': '45244253',
#   'ds': 'GDSN',
#   'manu': 'Green Bay Dressed Beef LLC'},
#  {'offset': 16,
#   'group': 'Branded Food Products Database',
#   'name': 'RENAISSANCE FOOD GROUP, HOT SALSA, SPICY, UPC: 826766144020',
#   'ndbno': '45109133',
#   'ds': 'LI',
#   'manu': 'RENAISSANCE FOOD GROUP, LLC'},
#  {'offset': 17,
#   'group': 'Branded Food Products Database',
#   'name': 'RENAISSANCE FOOD GROUP, SEASONED SOUTHWEST VEGETABLES, UPC: 826766783601',
#   'ndbno': '45186297',
#   'ds': 'LI',
#   'manu': 'RENAISSANCE FOOD GROUP, LLC'},
#  {'offset': 18,
#   'group': 'Branded Food Products Database',
#   'name': 'PAPER MAGIC GROUP, NICKELODEON PAW PATROL VALENTINE CARDS & CANDY, CHERRY, UPC: 073168708583',
#   'ndbno': '45158886',
#   'ds': 'LI',
#   'manu': 'none'},
#  {'offset': 19,
#   'group': 'Branded Food Products Database',
#   'name': 'FOURSTAR GROUP, ICING DECORATIONS, UPC: 049696990424',
#   'ndbno': '45174233',
#   'ds': 'LI',
#   'manu': 'Fourstar Group USA Inc.'},
#  {'offset': 20,
#   'group': 'Branded Food Products Database',
#   'name': 'PRAIM GROUP, TASTE THE MAGIC COOKIES AND CREAM PATTIES, UPC: 898136005187',
#   'ndbno': '45160139',
#   'ds': 'LI',
#   'manu': 'none'},
#  {'offset': 21,
#   'group': 'Branded Food Products Database',
#   'name': 'GOOD FOODS GROUP, GREEN WITH ENVY, 100% FRUIT & VEGETABLE JUICE, UPC: 736798902645',
#   'ndbno': '45153565',
#   'ds': 'LI',
#   'manu': 'Good Foods Group, LLC'},
#  {'offset': 22,
#   'group': 'Branded Food Products Database',
#   'name': 'RENAISSANCE FOOD GROUPS LLC, FRESH SPICY BLACK BEAN & CORN GUACAMOLE, UPC: 826766116935',
#   'ndbno': '45179895',
#   'ds': 'LI',
#   'manu': 'RENAISSANCE FOOD GROUP, LLC'},
#  {'offset': 23,
#   'group': 'Branded Food Products Database',
#   'name': 'HORIZON GROUP USA, GUMMY WORMS CANDY KIT, UPC: 765940593554',
#   'ndbno': '45145907',
#   'ds': 'LI',
#   'manu': 'Horizon Group USA, Inc.'},
#  {'offset': 24,
#   'group': 'Branded Food Products Database',
#   'name': 'HORIZON GROUP USA, GLOW POPS - LOLLIPOPS, UPC: 765940593585',
#   'ndbno': '45149675',
#   'ds': 'LI',
#   'manu': 'Horizon Group USA, Inc.'},
#  {'offset': 25,
#   'group': 'Branded Food Products Database',
#   'name': 'PRAIM GROUP, PREMIUM MILK CHOCOLATE, UPC: 898136004524',
#   'ndbno': '45159700',
#   'ds': 'LI',
#   'manu': 'PRAIM GROUP'},
#  {'offset': 26,
#   'group': 'Branded Food Products Database',
#   'name': 'GROUP RAISED GROUND VEAL, UPC: 636289090168',
#   'ndbno': '45366128',
#   'ds': 'LI',
#   'manu': 'Strauss Brands Incorporated'},
#  {'offset': 27,
#   'group': 'Vegetables and Vegetable Products',
#   'name': 'Brussels sprouts, raw',
#   'ndbno': '11098',
#   'ds': 'SR',
#   'manu': 'none'},
#  {'offset': 28,
#   'group': 'Vegetables and Vegetable Products',
#   'name': 'Cabbage, raw',
#   'ndbno': '11109',
#   'ds': 'SR',
#   'manu': 'none'},
#  {'offset': 29,
#   'group': 'Vegetables and Vegetable Products',
#   'name': 'Cabbage, red, raw',
#   'ndbno': '11112',
#   'ds': 'SR',
#   'manu': 'none'},
#  {'offset': 30,
#   'group': 'Vegetables and Vegetable Products',
#   'name': 'Cabbage, savoy, raw',
#   'ndbno': '11114',
#   'ds': 'SR',
#   'manu': 'none'},
#  {'offset': 31,
#   'group': 'Vegetables and Vegetable Products',
#   'name': 'Cabbage, chinese (pak-choi), raw',
#   'ndbno': '11116',
#   'ds': 'SR',
#   'manu': 'none'},
#  {'offset': 32,
#   'group': 'Vegetables and Vegetable Products',
#   'name': 'Cabbage, chinese (pe-tsai), raw',
#   'ndbno': '11119',
#   'ds': 'SR',
#   'manu': 'none'},
#  {'offset': 33,
#   'group': 'Vegetables and Vegetable Products',
#   'name': 'Cauliflower, raw',
#   'ndbno': '11135',
#   'ds': 'SR',
#   'manu': 'none'},
#  {'offset': 34,
#   'group': 'Vegetables and Vegetable Products',
#   'name': 'Kale, raw',
#   'ndbno': '11233',
#   'ds': 'SR',
#   'manu': 'none'},
#  {'offset': 35,
#   'group': 'Vegetables and Vegetable Products',
#   'name': 'Kohlrabi, raw',
#   'ndbno': '11241',
#   'ds': 'SR',
#   'manu': 'none'},
#  {'offset': 36,
#   'group': 'Vegetables and Vegetable Products',
#   'name': 'Mustard spinach, (tendergreen), raw',
#   'ndbno': '11274',
#   'ds': 'SR',
#   'manu': 'none'},
#  {'offset': 37,
#   'group': 'Vegetables and Vegetable Products',
#   'name': 'Radishes, oriental, raw',
#   'ndbno': '11430',
#   'ds': 'SR',
#   'manu': 'none'},
#  {'offset': 38,
#   'group': 'Vegetables and Vegetable Products',
#   'name': 'Turnips, raw',
#   'ndbno': '11564',
#   'ds': 'SR',
#   'manu': 'none'},
#  {'offset': 39,
#   'group': 'Vegetables and Vegetable Products',
#   'name': 'Turnip greens, raw',
#   'ndbno': '11568',
#   'ds': 'SR',
#   'manu': 'none'},
#  {'offset': 40,
#   'group': 'Vegetables and Vegetable Products',
#   'name': 'Cauliflower, green, raw',
#   'ndbno': '11965',
#   'ds': 'SR',
#   'manu': 'none'}]

# %% [markdown]
# call api data
# if response code is 200
#     status = True
#     ...
# else:
#     status = False

# %%
url = 'https://api.nal.usda.gov/ndb/list'
key = 'uC7EeReDRVWw7Kzijvvn8LtCDWR3D6hPyksxuFTW'
params = (('format', 'json'),('it', 'g'),('api_key', key))
response = requests.get(url, params = params)

group = response.json()
group
# Out:
# {'list': {'lt': 'f',
#   'start': 0,
#   'end': 50,
#   'total': 50,
#   'sr': '1',
#   'sort': 'n',
#   'item': [{'offset': 0,
#     'id': '45291778',
#     'name': ' ALL NATURAL ICE CREAM, UPC: 07203651151'},
#    {'offset': 1, 'id': '45213909', 'name': ' ALMOND MILK, UPC: 041220970063'},
#    {'offset': 2,
#     'id': '45357270',
#     'name': ' ARTISAN SMOOTH & CREAMY GELATO, UPC: 072431004278'},
#    {'offset': 3,
#     'id': '45033147',
#     'name': ' BARBECUE SAUCE, UPC: 741643022584'},
#    {'offset': 4,
#     'id': '45372502',
#     'name': ' BASIL PARMESAN CHICKEN, UPC: 041498097127'},
#    {'offset': 5,
#     'id': '45062764',
#     'name': ' BERRY NUT BLEND BREAKFAST IN THE GO! , UPC: 010300064220'},
#    {'offset': 6,
#     'id': '45236813',
#     'name': ' CARAMELIZED RED ONION CHUTNEY, UPC: 858723003033'},
#    {'offset': 7,
#     'id': '45051425',
#     'name': ' CARROT CAKE & FROSTING MIX, UPC: 072036708830'},
#    {'offset': 8,
#     'id': '45238262',
#     'name': ' COCONUT WATER BARS, UPC: 853883003374'},
#    {'offset': 9,
#     'id': '45107557',
#     'name': ' CRAWFISH, SHRIMP & CRAB BOIL, UPC: 071429018006'},
#    {'offset': 10,
#     'id': '45256938',
#     'name': ' DIPPS CHOCOLATEY COVERED GRANOLA BARS, UPC: 030000560822'},
#    {'offset': 11,
#     'id': '45220462',
#     'name': ' EARL GREY TEA T-STICK, UPC: 182801000516'},
#    {'offset': 12,
#     'id': '45333561',
#     'name': ' FLAVORED POTATO CHIPS, UPC: 021130293841'},
#    {'offset': 13,
#     'id': '45284757',
#     'name': ' FRENCH BREAD, UPC: 701990000086'},
#    {'offset': 14,
#     'id': '45325770',
#     'name': ' FRUIT ON THE BOTTOM COTTAGE CHEESE, UPC: 041483041586'},
#    {'offset': 15,
#     'id': '45374984',
#     'name': ' GOURMET MAYAN SUPERFOOD CACAO POWDER, UPC: 028744300354'},
#    {'offset': 16,
#     'id': '45269874',
#     'name': ' HOT CHOCO LATE, UPC: 878589001707'},
#    {'offset': 17, 'id': '45229431', 'name': ' ICE CREAM, UPC: 03003400229'},
#    {'offset': 18,
#     'id': '45055584',
#     'name': ' INSTANT HOT COCOA MIX, UPC: 741643022607'},
#    {'offset': 19,
#     'id': '45159650',
#     'name': ' JUICE COCKTAIL BLEND FROM CONCENTRATE, UPC: 888670026175'},
#    {'offset': 20,
#     'id': '45338920',
#     'name': ' JUICE COCKTAIL FROM CONCENTRATE, UPC: 021130313808'},
#    {'offset': 21,
#     'id': '45355541',
#     'name': ' LINGUINE ENRICHED MACARONI PRODUCT, UPC: 041303000533'},
#    {'offset': 22,
#     'id': '45333532',
#     'name': ' MARSHMALLOW MICE, UPC: 049022974395'},
#    {'offset': 23,
#     'id': '45054808',
#     'name': ' NUTS & SEEDS, UPC: 071725742094'},
#    {'offset': 24, 'id': '45316680', 'name': ' OAT GRAHAMS, UPC: 61232200059'},
#    {'offset': 25,
#     'id': '45289149',
#     'name': ' ORGANIC OLIVE OIL, UPC: 074305020322'},
#    {'offset': 26,
#     'id': '45181458',
#     'name': ' PREMIUM GELATO SWIRLS, UPC: 020735112496'},
#    {'offset': 27,
#     'id': '45142339',
#     'name': ' PREMIUM TEA BAGS, UPC: 020700006201'},
#    {'offset': 28,
#     'id': '45218402',
#     'name': ' PRETZEL BURGER, UPC: 074121010886'},
#    {'offset': 29,
#     'id': '45036496',
#     'name': ' RAW ORGANIC HONEY, UPC: 072223001133'},
#    {'offset': 30,
#     'id': '45255677',
#     'name': ' RAW UNFILTERED SOUTHERN CALIFORNIA HONEY, UPC: 853508103007'},
#    {'offset': 31,
#     'id': '45355890',
#     'name': ' REDUCED FAT ICE CREAM, UPC: 041130310928'},
#    {'offset': 32,
#     'id': '45195084',
#     'name': ' SAN MARZANO REGION DICED TOMATOES, UPC: 03003410088'},
#    {'offset': 33, 'id': '45290540', 'name': ' SELTZER, UPC: 071537021042'},
#    {'offset': 34,
#     'id': '45259588',
#     'name': ' SILKY SMOOTH TRUFFLE HEARTS , UPC: 040000484042'},
#    {'offset': 35,
#     'id': '45324106',
#     'name': ' SLOPPY BOUDREAUX, UPC: 036921162541'},
#    {'offset': 36,
#     'id': '45237588',
#     'name': ' SPARKLING SPRING WATER, UPC: 654871000432'},
#    {'offset': 37,
#     'id': '45315476',
#     'name': ' SUPERFOOD BAR , UPC: 852684003729'},
#    {'offset': 38,
#     'id': '45229708',
#     'name': ' THE DUGOUT GUM, UPC: 059642321646'},
#    {'offset': 39,
#     'id': '45191254',
#     'name': ' THIN CRUST GOURMET FLATBREAD PIZZA, UPC: 07203671413'},
#    {'offset': 40,
#     'id': '45172355',
#     'name': ' TRIPLE LAYER CHOCOLATE FUDGE CAKE, UPC: 029519233792'},
#    {'offset': 41,
#     'id': '45278337',
#     'name': ' UNPEELED APRICOT HALVES, UPC: 021130321148'},
#    {'offset': 42,
#     'id': '45288703',
#     'name': ' WHOLE GRAIN BREAD, UPC: 857434002052'},
#    {'offset': 43,
#     'id': '45279368',
#     'name': ' WHOLE STRAWBERRIES, UPC: 075450016277'},
#    {'offset': 44,
#     'id': '45137745',
#     'name': '!AJUA!, CAFFEINE FREE SODA, MANDARIN ORANGE, UPC: 061500127178'},
#    {'offset': 45,
#     'id': '45137747',
#     'name': '!AJUA!, CAFFEINE FREE SODA, PINEAPPLE, UPC: 061500127161'},
#    {'offset': 46,
#     'id': '45137744',
#     'name': '!AJUA!, CAFFEINE FREE SODA, TUTTI FRUITTI FRUIT PUNCH, UPC: 061500127154'},
#    {'offset': 47,
#     'id': '45166389',
#     'name': '!HOLLA NOLLA!, BON TEMPS!, REAL RESTAURANT TORTILLA CHIPS, UPC: 810395026048'},
#    {'offset': 48,
#     'id': '45138560',
#     'name': '"" A LATE ONE"" SOFT DRINK, UPC: 072275100204'},
#    {'offset': 49,
#     'id': '45369255',
#     'name': '""BACN,BITS,FC,1/4IN DICE,SMFD,2/5#"", PREPARED, GTIN: 10070800142313'}]}}
